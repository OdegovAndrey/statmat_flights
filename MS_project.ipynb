# %%
import csv
import tqdm             
import numpy as np

# %% [markdown]
# #### Просто гистограммы

# %%
with open(r'combined_file.csv', newline='') as f:
    reader = csv.reader(f)
    headers = next(reader)  # Get the header row
    DEP_TIME_index = headers.index('DEP_TIME')
    CRS_DEP_TIME_index = headers.index('CRS_DEP_TIME')
    DEP_DELAY_index = headers.index('DEP_DELAY')
    ORIGIN_AIRPORT_ID_index = headers.index('ORIGIN_AIRPORT_ID')
    ARR_TIME_index = headers.index('ARR_TIME')
    CRS_ARR_TIME_index = headers.index('CRS_ARR_TIME')
    ARR_DELAY_index = headers.index('ARR_DELAY')
    WHEELS_OFF_index = headers.index('WHEELS_OFF')
    WHEELS_ON_index = headers.index('WHEELS_ON')
    TAXI_OUT_index = headers.index('TAXI_OUT')
    TAXI_IN_index = headers.index('TAXI_IN')
    DISTANCE_index = headers.index('DISTANCE')
    AIR_TIME_index = headers.index('AIR_TIME')
    CRS_ELAPSED_TIME_index = headers.index('CRS_ELAPSED_TIME')
    ACTUAL_ELAPSED_TIME_index = headers.index('ACTUAL_ELAPSED_TIME')
    CRS_ARR_TIME_index = headers.index('CRS_ARR_TIME')




    n = int(1e6)
    DEP_TIME_array = np.zeros(n, dtype=float)
    CRS_DEP_TIME_array = np.zeros(n, dtype=float)
    DEP_DELAY_array = np.zeros(n, dtype=float)
    ORIGIN_AIRPORT_ID_array = np.zeros(n, dtype=float)
    ARR_TIME_array = np.zeros(n, dtype=float)
    CRS_ARR_TIME_array = np.zeros(n, dtype=float)
    ARR_DELAY_array = np.zeros(n, dtype=float)
    WHEELS_OFF_array = np.zeros(n, dtype=float)
    WHEELS_ON_array = np.zeros(n, dtype=float)
    TAXI_OUT_array = np.zeros(n, dtype=float)
    TAXI_IN_array = np.zeros(n, dtype=float)
    DISTANCE_array = np.zeros(n, dtype=float)
    AIR_TIME_array = np.zeros(n, dtype=float)
    CRS_ELAPSED_TIME_array = np.zeros(n, dtype=float)
    ACTUAL_ELAPSED_TIME_array = np.zeros(n, dtype=float)
    CRS_ARR_TIME_array = np.zeros(n, dtype=float)



    for count in tqdm.tqdm(range(n)):
        row = next(reader)
        if (row[DEP_TIME_index]!='') and (row[WHEELS_OFF_index]!='') and (row[TAXI_OUT_index]!='') and (row[DISTANCE_index]!='') and (row[AIR_TIME_index]!='') and (row[WHEELS_ON_index]!='') and (row[TAXI_IN_index]!='') and (row[DEP_DELAY_index]!='') and (row[ARR_TIME_index]!='') and (row[ARR_DELAY_index]!='') and (row[ORIGIN_AIRPORT_ID_index]!='') and (row[CRS_DEP_TIME_index]!='') and (row[CRS_ARR_TIME_index]!='') and (row[CRS_ELAPSED_TIME_index]!='') and (row[ACTUAL_ELAPSED_TIME_index]!='') and (row[CRS_ARR_TIME_index]!=''):
            if row[DEP_TIME_index]!='':
                DEP_TIME_array[count] = row[DEP_TIME_index]
            if row[WHEELS_OFF_index]!='':
                WHEELS_OFF_array[count] = row[WHEELS_OFF_index]
            if row[TAXI_OUT_index]!='':
                TAXI_OUT_array[count] = row[TAXI_OUT_index]
            if row[DISTANCE_index]!='':
                DISTANCE_array[count] = row[DISTANCE_index]
            if row[AIR_TIME_index]!='':
                AIR_TIME_array[count] = row[AIR_TIME_index]
            if row[WHEELS_ON_index]!='':
                WHEELS_ON_array[count] = row[WHEELS_ON_index]
            if row[TAXI_IN_index]!='':
                TAXI_IN_array[count] = row[TAXI_IN_index]
            if row[DEP_DELAY_index]!='':
                DEP_DELAY_array[count] = row[DEP_DELAY_index]
            if row[ARR_TIME_index]!='':
                ARR_TIME_array[count] = row[ARR_TIME_index]
            if row[ARR_DELAY_index]!='':
                ARR_DELAY_array[count] = row[ARR_DELAY_index]
            if row[ORIGIN_AIRPORT_ID_index]!='':
                ORIGIN_AIRPORT_ID_array[count] = row[ORIGIN_AIRPORT_ID_index]
            if row[CRS_DEP_TIME_index]!='':
                CRS_DEP_TIME_array[count] = row[CRS_DEP_TIME_index]
            if row[CRS_ARR_TIME_index]!='':
                CRS_ARR_TIME_array[count] = row[CRS_ARR_TIME_index]
            if row[CRS_ELAPSED_TIME_index]!='':
                CRS_ELAPSED_TIME_array[count] = row[CRS_ELAPSED_TIME_index]
            if row[ACTUAL_ELAPSED_TIME_index]!='':
                ACTUAL_ELAPSED_TIME_array[count] = row[ACTUAL_ELAPSED_TIME_index]
            if row[CRS_ARR_TIME_index]!='':
                CRS_ARR_TIME_array[count] = row[CRS_ARR_TIME_index]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
array = CRS_DEP_TIME_array
minutes = []

for time in array:
    hours = int(time // 100)
    minute = int(time % 100)
    total_minutes = hours * 60 + minute
    minutes.append(total_minutes)   #использование вместо minutes

arr = [x for x in minutes]

plt.hist(arr, bins=200, density=True, alpha=0.6)
plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.title('Планируемое время отправления (местное время, мин с начала суток)')
plt.show()


plt.legend()
plt.show()
# plt.savefig('dep_time.png')

# %%
array = DEP_TIME_array
minutes = []

for time in array:
    hours = int(time // 100)
    minute = int(time % 100)
    total_minutes = hours * 60 + minute
    minutes.append(total_minutes)   #использование вместо minutes

arr = [x for x in minutes]

plt.hist(arr, bins=200, density=True, alpha=0.6)
plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.title('Реальное время отправления (местное время, мин с начала суток)')
plt.show()


plt.show()
# plt.savefig('dep_time.png')

# %%
times_1 = DEP_TIME_array
times_2 = CRS_DEP_TIME_array
minutes_1 = []
minutes_2 = []
result = []

for time in times_1:
    hours = int(time // 100)
    minutes = int(time % 100)
    total_minutes = hours * 60 + minutes
    minutes_1.append(total_minutes)

for time in times_2:
    hours = int(time // 100)
    minutes = int(time % 100)
    total_minutes = hours * 60 + minutes
    minutes_2.append(total_minutes)

for i in range(len(minutes_1)):
    diff = minutes_1[i] - minutes_2[i]
    result.append(diff)

arr = [x for x in result if x > -100 and x < 200 and x != 0]

sns.kdeplot(arr, label='Распределение', color='blue')

plt.title('Разность между фактическим и планируемым временами отправления (мин)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()
plt.savefig('dep_time.png')

# %%
data = sorted(arr)
from fitter import Fitter
f = Fitter(data, distributions=['gamma', 'norm','lognorm'\])
f.fit()
# may take some time since by default, all distributions are tried
# but you call manually provide a smaller set of distributions
f.summary()

# %%
times_1 = WHEELS_OFF_array
times_2 = DEP_TIME_array
minutes_1 = []
minutes_2 = []
result = []

for time in times_1:
    hours = int(time // 100)
    minutes = int(time % 100)
    total_minutes = hours * 60 + minutes
    minutes_1.append(total_minutes)

for time in times_2:
    hours = int(time // 100)
    minutes = int(time % 100)
    total_minutes = hours * 60 + minutes
    minutes_2.append(total_minutes)

for i in range(len(minutes_1)):
    diff = abs(minutes_1[i] - minutes_2[i])
    result.append(diff)

arr = [x for x in result if x < 500 and x != 0]

plt.hist(arr, bins = 500, color='blue', alpha=0.7)
plt.title('Разница между временем отрыва от земли и фактическим временем отправления (мин)')
plt.xlabel('Значение')
plt.ylabel('Частота')

plt.show()

# %%
array = WHEELS_OFF_array
minutes = []

for time in array:
    hours = int(time // 100)
    minute = int(time % 100)
    total_minutes = hours * 60 + minute
    minutes.append(total_minutes)   #использование вместо minutes

arr = [x for x in minutes if x!=0]

plt.hist(arr, bins=200, density=True, alpha=0.6)
plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.title('Время отрыва от земли (местное время, мин)')
plt.show()


plt.show()

# %%
array = WHEELS_ON_array
minutes = []

for time in array:
    hours = int(time // 100)
    minute = int(time % 100)
    total_minutes = hours * 60 + minute
    minutes.append(total_minutes)   #использование вместо minutes

arr = [x for x in minutes if x !=0]

plt.hist(arr, bins=200, density=True, alpha=0.6)
plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.title('Время приземления (местное время, мин)')
plt.show()


plt.show()

# %%
array = TAXI_OUT_array
arr = [x for x in array if x != 0 and x < 100]

plt.hist(arr, bins=200, density=True, alpha=0.6)
plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.title('Разница между временем отрыва от земли и фактическим временем отправления (мин)') #referring to the period of time between when an airplane leaves the gate and when it takes off
plt.show()

# %%
array = TAXI_IN_array
arr = [x for x in array if x != 0 and x < 100]

plt.hist(arr, bins=200, density=True, alpha=0.6)
plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.title('Разница между временем посадки и фактическим временем прибытия (мин)')
plt.show()

# %%
array = DISTANCE_array
arr = [x for x in array if x != 0 and x < 3200]


sns.kdeplot(arr, label='Распределение', color='blue')

plt.title('Дистанция полёта (мили)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
array = AIR_TIME_array
arr = [x for x in array if x != 0 and x < 500]

sns.kdeplot(arr, label='Распределение', color='blue')

plt.title('Время в воздухе (мин)')
plt.xlabel('Значение')
plt.ylabel('Плотность')

plt.legend()
plt.show()

# %%
array = CRS_ELAPSED_TIME_array - ACTUAL_ELAPSED_TIME_array
arr = [x for x in array if x > -100 and x < 100]

plt.hist(arr, bins=400, density=True, alpha=0.6)
plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.title('Разница между запланированным временем всего полёта и фактическим (мин)')
plt.show()

# %%
array = DEP_DELAY_array
arr = [x for x in array if x < 200]

sns.kdeplot(arr, label='Распределение', color='blue', warn_singular=False)

plt.title('Перенос вылета (мин)')
plt.xlabel('Значение')
plt.ylabel('Плотность')

plt.legend()
plt.show()

# %%
array = ARR_TIME_array
minutes = []

for time in array:
    hours = int(time // 100)
    minute = int(time % 100)
    total_minutes = hours * 60 + minute
    minutes.append(total_minutes)   #использование вместо minutes

arr = [x for x in minutes]

plt.hist(arr, bins=200, density=True, alpha=0.6)
plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.title('Реальное время прибытия (местное время, мин с начала суток)')
plt.show()


plt.show()

# %%
array = CRS_ARR_TIME_array
minutes = []

for time in array:
    hours = int(time // 100)
    minute = int(time % 100)
    total_minutes = hours * 60 + minute
    minutes.append(total_minutes)   #использование вместо minutes

arr = [x for x in minutes]

plt.hist(arr, bins=200, density=True, alpha=0.6)
plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.title('Планируемое время прибытия (местное время, мин с начала суток)')
plt.show()


plt.legend()
plt.show()

# %%
times_1 = ARR_TIME_array
times_2 = CRS_ARR_TIME_array
minutes_1 = []
minutes_2 = []
result = []

for time in times_1:
    hours = int(time // 100)
    minutes = int(time % 100)
    total_minutes = hours * 60 + minutes
    minutes_1.append(total_minutes)

for time in times_2:
    hours = int(time // 100)
    minutes = int(time % 100)
    total_minutes = hours * 60 + minutes
    minutes_2.append(total_minutes)

for i in range(len(minutes_1)):
    diff = minutes_1[i] - minutes_2[i]
    result.append(diff)

arr = [x for x in result if x > -100 and x < 200]

sns.kdeplot(arr, label='Распределение', color='blue')

plt.title('Разность между фактическим и планируемым временами прибытия (мин)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()
# plt.savefig('dep_time.png')

# %%
times_2 = WHEELS_ON_array
times_1 = ARR_TIME_array
minutes_1 = []
minutes_2 = []
result = []

for time in times_1:
    hours = int(time // 100)
    minutes = int(time % 100)
    total_minutes = hours * 60 + minutes
    minutes_1.append(total_minutes)

for time in times_2:
    hours = int(time // 100)
    minutes = int(time % 100)
    total_minutes = hours * 60 + minutes
    minutes_2.append(total_minutes)

for i in range(len(minutes_1)):
    diff = minutes_1[i] - minutes_2[i]
    result.append(diff)

arr = [x for x in result if x < 100 and x != 0]

plt.hist(arr, bins = 200, color='blue', alpha=0.7)
plt.title('Разница между временем приземления и фактическим временем прибытия (мин)')
plt.xlabel('Значение')
plt.ylabel('Частота')

plt.show()

# %%
array = ARR_DELAY_array
arr = [x for x in array if x != 1 and x < 200]

sns.kdeplot(arr, label='Распределение', color='blue', warn_singular=False)

plt.title('Перенос прилёта (мин)')
plt.xlabel('Значение')
plt.ylabel('Плотность')

plt.legend()
plt.show()

# %% [markdown]
# #### По аэропортам

# %%
from collections import defaultdict

airport_data = defaultdict(list)

with open(r'combined_file.csv', newline='') as f:  #combined_file Jan2024
    reader = csv.reader(f)
    headers = next(reader)  # Get the header row
    DEP_TIME_index = headers.index('DEP_TIME') #есть
    CRS_DEP_TIME_index = headers.index('CRS_DEP_TIME')
    DEP_DELAY_index = headers.index('DEP_DELAY') #есть
    ARR_TIME_index = headers.index('ARR_TIME') #есть
    ARR_DELAY_index = headers.index('ARR_DELAY') #есть
    WHEELS_OFF_index = headers.index('WHEELS_OFF') #есть
    WHEELS_ON_index = headers.index('WHEELS_ON') #есть (графики для вилс он в точности совпадают с графиками арр тайм)
    TAXI_OUT_index = headers.index('TAXI_OUT') #есть
    TAXI_IN_index = headers.index('TAXI_IN') #есть
    DISTANCE_index = headers.index('DISTANCE') #есть
    AIR_TIME_index = headers.index('AIR_TIME') #есть
    ORIGIN_AIRPORT_ID_index = headers.index('ORIGIN_AIRPORT_ID')

    for row in tqdm.tqdm(reader):
        if all(row[index] for index in [DEP_TIME_index, WHEELS_OFF_index, TAXI_OUT_index, DISTANCE_index, AIR_TIME_index, ORIGIN_AIRPORT_ID_index, DEP_DELAY_index, ARR_TIME_index, ARR_DELAY_index, WHEELS_ON_index, TAXI_IN_index, CRS_DEP_TIME_index]):
            airport_id = row[ORIGIN_AIRPORT_ID_index]
            flight_data = [row[DEP_TIME_index], row[WHEELS_OFF_index], row[TAXI_OUT_index], row[DISTANCE_index], row[AIR_TIME_index], row[DEP_DELAY_index], row[ARR_TIME_index], row[ARR_DELAY_index], row[WHEELS_ON_index], row[TAXI_IN_index], row [CRS_DEP_TIME_index]]
            airport_data[airport_id].append(flight_data)

# %%
arr_ids_and_flights = []
for airport_id, flight_data_list in airport_data.items():
    # print(f"Airport ID: {airport_id}")
    # for flight_data in flight_data_list:
    #     print(f"  Flight Data: {flight_data}")
    arr_ids_and_flights.append([airport_id, len(flight_data_list)])
    print (len(flight_data_list))

# %%
arr_ids_and_flights.sort(key=lambda x: x[1])
arr_ids_and_flights = arr_ids_and_flights[::-1]
print(arr_ids_and_flights)

# %%
import pandas as pd

# %%
data = pd.read_csv('combined_file.csv')

filtered_data_1 = data[data['ORIGIN_AIRPORT_ID'] == 10397]
filtered_data_2 = data[data['ORIGIN_AIRPORT_ID'] == 11292]
filtered_data_3 = data[data['ORIGIN_AIRPORT_ID'] == 11298]
# filtered_data_4 = data[data['ORIGIN_AIRPORT_ID'] == 13930]
# filtered_data_5 = data[data['ORIGIN_AIRPORT_ID'] == 11057]
# filtered_data_6 = data[data['ORIGIN_AIRPORT_ID'] == 12892]
# filtered_data_7 = data[data['ORIGIN_AIRPORT_ID'] == 12889]
# filtered_data_8 = data[data['ORIGIN_AIRPORT_ID'] == 14107]
# filtered_data_9 = data[data['ORIGIN_AIRPORT_ID'] == 13204]
# filtered_data_10 = data[data['ORIGIN_AIRPORT_ID'] == 12953]

# %%
filtered_data_1.loc[:, 'DEP_TIME'] = filtered_data_1.loc[:, 'DEP_TIME'].astype(str).str.zfill(4)  # приведем время к формату ЧЧММ, добавив нули спереди при необходимости
print(filtered_data_1.loc[:, 'DEP_TIME'])
# filtered_data_1.loc[:, 'DEP_TIME'] = filtered_data_1.loc[:, 'DEP_TIME'].str.slice(0, 2).astype(int) * 60 + filtered_data_1.loc[:, 'DEP_TIME'].str.slice(2, 4).astype(int)  # переведем время в минуты
# Перевод массива DEP_TIME в минуты

# filtered_data_1.loc[:, 'DEP_TIME'] = pd.to_datetime(filtered_data_1['DEP_TIME']).dt.hour * 60 + pd.to_datetime(filtered_data_1['DEP_TIME']).dt.minute

# %%
plt.hist(arr, bins=200, density=True, alpha=0.6)
plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.title('Реальное время прибытия (местное время, мин с начала суток)')
plt.show()


plt.show()

# %%
# sns.kdeplot(filtered_data_1['AIR_TIME'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_1['AIR_TIME'], clip=(0, 400), label='Распределение', color='blue', warn_singular=False)

plt.title('Время в воздухе для аэропорта 10397 (топ-1 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_2['AIR_TIME'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_2['AIR_TIME'], clip=(0, 250), label='Распределение', color='blue', warn_singular=False)

plt.title('Время в воздухе для аэропорта 11292 (топ-2 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_3['AIR_TIME'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_3['AIR_TIME'], clip=(0, 300), label='Распределение', color='blue', warn_singular=False)

plt.title('Время в воздухе для аэропорта 11298 (топ-3 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# Перевод массива DEP_TIME в минуты с учетом NaN значений
DEP_TIME_array = filtered_data_1['DEP_TIME'].values
minutes_DEP_TIME = []
for time in DEP_TIME_array:
    if not np.isnan(time):
        hours = int(time // 100)
        minutes = int(time % 100)
        total_minutes = hours * 60 + minutes
        minutes_DEP_TIME.append(total_minutes)

# Перевод массива CRS_DEP_TIME в минуты с учетом NaN значений
CRS_DEP_TIME_array = filtered_data_1['CRS_DEP_TIME'].values
minutes_CRS_DEP_TIME = []
for time in CRS_DEP_TIME_array:
    if not np.isnan(time):
        hours = int(time // 100)
        minutes = int(time % 100)
        total_minutes = hours * 60 + minutes
        minutes_CRS_DEP_TIME.append(total_minutes)

# Получение разницы между DEP_TIME и CRS_DEP_TIME в минутах
difference = [abs(a - b) for a, b in zip(minutes_DEP_TIME, minutes_CRS_DEP_TIME) if not np.isnan(a) and not np.isnan(b)]

# Фильтрация разницы
filtered_difference = [x for x in difference if x > -100 and x < 200 and x != 0]

# Построение графика
sns.kdeplot(filtered_difference, label='Распределение', color='blue')

plt.title('Разность между фактическим и планируемым временами отправления (мин)')
plt.xlabel('Значение')
plt.ylabel('Плотность')

# Добавление элемента в легенду
plt.legend(['Распределение'])

plt.show()

# %%
sns.kdeplot(filtered_data_1['DEP_TIME'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время отправления для аэропорта 10397 (топ-1 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(filtered_data_2['DEP_TIME'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время отправления для аэропорта 11292 (топ-2 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(filtered_data_3['DEP_TIME'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время отправления для аэропорта 11298 (топ-3 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(filtered_data_1['WHEELS_OFF'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время отрыва от земли для аэропорта 10397 (топ-1 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(filtered_data_2['WHEELS_OFF'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время отрыва от земли для аэропорта 11292 (топ-2 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(filtered_data_3['WHEELS_OFF'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время отрыва от земли для аэропорта 11298 (топ-3 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(filtered_data_1['WHEELS_ON'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время приземления для аэропорта 10397 (топ-1 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(filtered_data_2['WHEELS_ON'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время приземления для аэропорта 11292 (топ-2 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(filtered_data_3['WHEELS_ON'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время приземления для аэропорта 11298 (топ-3 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_1['TAXI_OUT'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_1['TAXI_OUT'], clip=(0, 75), label='Распределение', color='blue', warn_singular=False)

plt.title('Время катания по аэропорту перед вылетом для аэропорта 10397 (топ-1 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_2['TAXI_OUT'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_2['TAXI_OUT'], clip=(0, 100), label='Распределение', color='blue', warn_singular=False)

plt.title('Время катания по аэропорту перед вылетом для аэропорта 11292 (топ-2 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_3['TAXI_OUT'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_1['TAXI_OUT'], clip=(0, 100), label='1', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_2['TAXI_OUT'], clip=(0, 100), label='2', color='red', warn_singular=False)
sns.kdeplot(data=filtered_data_3['TAXI_OUT'], clip=(0, 100), label='3', color='green', warn_singular=False)


plt.title('Время катания по аэропорту перед вылетом для топ-3 по числу вылетов, мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(data=filtered_data_1['TAXI_IN'], clip=(0, 50), label='Распределение', color='blue', warn_singular=False)

plt.title('Время катания по аэропорту после прилёта для аэропорта 10397 (топ-1 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
from scipy.stats import gaussian_kde

filtered_data = filtered_data_1['TAXI_IN']
filtered_data = filtered_data[(filtered_data >= -10) & (filtered_data <= 50)]

density, bins, _ = plt.hist(filtered_data, bins=50, density=True, alpha=0)
kde = gaussian_kde(filtered_data, bw_method=0.1)
plt.plot(bins, kde(bins), color='blue', label='Распределение')

plt.title('Время катания по аэропорту после прилёта для аэропорта 10397 (топ-1 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')

plt.legend()
plt.show()

# %%
sns.kdeplot(data=filtered_data_2['TAXI_IN'], clip=(0, 50), label='Распределение', color='blue', warn_singular=False)

plt.title('Время катания по аэропорту после прилёта для аэропорта 11292 (топ-2 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
filtered_data = filtered_data_2['TAXI_IN']
filtered_data = filtered_data[(filtered_data > -5) & (filtered_data <= 50)]

density, bins, _ = plt.hist(filtered_data, bins=50, density=True, alpha=0)
kde = gaussian_kde(filtered_data, bw_method=0.1)
plt.plot(bins, kde(bins), color='blue', label='Распределение')

plt.title('Время катания по аэропорту после прилёта для аэропорта 11292 (топ-2 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')

plt.legend()
plt.show()

# %%
sns.kdeplot(data=filtered_data_3['TAXI_IN'], clip=(0, 50), label='Распределение', color='blue', warn_singular=False)

plt.title('Время катания по аэропорту после прилёта для аэропорта 11298 (топ-3 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
filtered_data = filtered_data_3['TAXI_IN']
filtered_data = filtered_data[(filtered_data >= 0) & (filtered_data <= 50)]

density, bins, _ = plt.hist(filtered_data, bins=50, density=True, alpha=0)
kde = gaussian_kde(filtered_data, bw_method=0.1)
plt.plot(bins, kde(bins), color='blue', label='Распределение')

plt.title('Время катания по аэропорту после прилёта для аэропорта 11298 (топ-3 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')

plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_1['DISTANCE'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_1['DISTANCE'], clip=(0, 2500), label='Распределение', color='blue', warn_singular=False)

plt.title('Дистанция полёта для аэропорта 10397 (топ-1 по числу вылетов), мили')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(data=filtered_data_2['DISTANCE'], clip=(0, 2000), label='Распределение', color='blue', warn_singular=False)

plt.title('Дистанция полёта для аэропорта 11292 (топ-2 по числу вылетов), мили')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_3['DISTANCE'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_3['DISTANCE'], clip=(0, 2000), label='Распределение', color='blue', warn_singular=False)

plt.title('Дистанция полёта для аэропорта 11298 (топ-3 по числу вылетов), мили')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_1['DEP_DELAY'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_1['DEP_DELAY'], clip=(-200, 200), label='Распределение', color='blue', warn_singular=False)

plt.title('Перенос вылета для аэропорта 10397 (топ-1 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_2['DEP_DELAY'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_2['DEP_DELAY'], clip=(-200, 200), label='Распределение', color='blue', warn_singular=False)

plt.title('Перенос вылета для аэропорта 11292 (топ-2 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_2['DEP_DELAY'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_3['DEP_DELAY'], clip=(-200, 200), label='Распределение', color='blue', warn_singular=False)

plt.title('Перенос вылета для аэропорта 11298 (топ-3 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(filtered_data_1['ARR_TIME'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время прибытия для аэропорта 10397 (топ-1 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(filtered_data_2['ARR_TIME'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время прибытия для аэропорта 11292 (топ-2 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
sns.kdeplot(filtered_data_3['ARR_TIME'], label='Распределение', color='blue', warn_singular=False)

plt.title('Время прибытия для аэропорта 11298 (топ-3 по числу вылетов)')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_1['ARR_DELAY'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_1['ARR_DELAY'], clip=(-200, 200), label='Распределение', color='blue', warn_singular=False)

plt.title('Перенос прилёта для аэропорта 10397 (топ-1 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_1['ARR_DELAY'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_2['ARR_DELAY'], clip=(-200, 200), label='Распределение', color='blue', warn_singular=False)

plt.title('Перенос прилёта для аэропорта 11292 (топ-2 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()

# %%
# sns.kdeplot(filtered_data_1['ARR_DELAY'], label='Распределение', color='blue', warn_singular=False)
sns.kdeplot(data=filtered_data_3['ARR_DELAY'], clip=(-200, 200), label='Распределение', color='blue', warn_singular=False)

plt.title('Перенос прилёта для аэропорта 11298 (топ-3 по числу вылетов), мин')
plt.xlabel('Значение')
plt.ylabel('Плотность')


plt.legend()
plt.show()
